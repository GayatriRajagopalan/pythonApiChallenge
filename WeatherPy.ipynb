# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !pip install citipy
# Out:
# ...
#      ---------------------------------------- 0.0/675.6 kB ? eta -:--:--
#       --------------------------------------- 10.2/675.6 kB ? eta -:--:--
#       --------------------------------------- 10.2/675.6 kB ? eta -:--:--
#      - ----------------------------------- 30.7/675.6 kB 187.9 kB/s eta 0:00:04
#      --- --------------------------------- 61.4/675.6 kB 328.2 kB/s eta 0:00:02
#      ------- ---------------------------- 143.4/675.6 kB 610.6 kB/s eta 0:00:01
#      --------------------------- ---------- 481.3/675.6 kB 1.8 MB/s eta 0:00:01
#      -------------------------------------  665.6/675.6 kB 2.2 MB/s eta 0:00:01
#      -------------------------------------- 675.6/675.6 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for citipy: filename=citipy-0.0.6-py3-none-any.whl size=675977 sha256=6b2fd80216bac86a60755a66a4b080685777a1c7140561ca0a5360c649b8d0de
# ...

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 587

# %%
#Solution
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
   

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 597

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = # YOUR CODE HERE

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = # YOUR CODE HERE

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = # YOUR CODE HERE

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = # YOUR CODE HERE
        city_lng = # YOUR CODE HERE
        city_max_temp = # YOUR CODE HERE
        city_humidity = # YOUR CODE HERE
        city_clouds = # YOUR CODE HERE
        city_wind = # YOUR CODE HERE
        city_country = # YOUR CODE HERE
        city_date = # YOUR CODE HERE

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kerikeri
# Processing Record 2 of Set 1 | ginir
# Processing Record 3 of Set 1 | margaret river
# Processing Record 4 of Set 1 | bam
# Processing Record 5 of Set 1 | marrakesh
# Processing Record 6 of Set 1 | waitangi
# Processing Record 7 of Set 1 | machico
# Processing Record 8 of Set 1 | port lincoln
# Processing Record 9 of Set 1 | howrah
# Processing Record 10 of Set 1 | leava
# Processing Record 11 of Set 1 | agat village
# Processing Record 12 of Set 1 | pacific grove
# Processing Record 13 of Set 1 | kitakata
# Processing Record 14 of Set 1 | qaqortoq
# Processing Record 15 of Set 1 | nadi
# Processing Record 16 of Set 1 | katsuura
# Processing Record 17 of Set 1 | adamstown
# Processing Record 18 of Set 1 | blackmans bay
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | buckeye
# Processing Record 21 of Set 1 | kozhevnikovo
# ...

# %%
#Solution
# Set the API base URL
from pprint import pprint
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    weather_response = requests.get(city_url)
    
    try:
        # Parse the JSON and retrieve data
        city_weather = weather_response.json()
        pprint(city_weather)
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
       
      
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -25.066, 'lon': -130.1015},
#  'dt': 1729714571,
#  'id': 4030723,
#  'main': {'feels_like': 293.59,
#           'grnd_level': 1013,
#           'humidity': 69,
#           'pressure': 1023,
#           'sea_level': 1023,
#           'temp': 293.68,
#           'temp_max': 293.68,
#           'temp_min': 293.68},
#  'name': 'Adamstown',
#  'sys': {'country': 'PN', 'sunrise': 1729691912, 'sunset': 1729738227},
#  'timezone': -28800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 84, 'gust': 7.28, 'speed': 6.77}}
# Processing Record 2 of Set 1 | cascais
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 38.6979, 'lon': -9.4215},
# ...

# %%
#Solution
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    weather_response = requests.get(city_url)
    
    try:
        # Parse the JSON and retrieve data
        city_weather = weather_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | vilyuchinsk
# Processing Record 3 of Set 1 | talnakh
# Processing Record 4 of Set 1 | hadibu
# Processing Record 5 of Set 1 | alta
# Processing Record 6 of Set 1 | college
# Processing Record 7 of Set 1 | kavieng
# Processing Record 8 of Set 1 | puerto natales
# Processing Record 9 of Set 1 | edinburgh of the seven seas
# Processing Record 10 of Set 1 | seven pagodas
# Processing Record 11 of Set 1 | santo antonio
# Processing Record 12 of Set 1 | luanda
# Processing Record 13 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 14 of Set 1 | soe
# Processing Record 15 of Set 1 | waitangi
# Processing Record 16 of Set 1 | fort bragg
# Processing Record 17 of Set 1 | zakamensk
# Processing Record 18 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 19 of Set 1 | tiksi
# ...

# %%
pd.DataFrame(city_data)
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    port-aux-francais -49.3500   70.2167    275.85        71          98
# 1          vilyuchinsk  52.9306  158.4028    276.30        95         100
# 2              talnakh  69.4865   88.3972    255.46        95          88
# 3               hadibu  12.6500   54.0333    299.77        85          35
# 4                 alta  69.9689   23.2717    271.74        86          40
# ..                 ...      ...       ...       ...       ...         ...
# 567             siwana  25.6333   72.4167    299.42        30           5
# 568         las khorey  11.1595   48.1967    302.15        70          18
# 569              eraan   9.0629  117.7016    299.47        92         100
# 570        gorom-gorom  14.4439   -0.2361    303.82        45          26
# 571               ghat  24.9647   10.1728    298.65        22           1
#
#      Wind Speed Country        Date
# 0         13.19      TF  1729727656
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = # YOUR CODE HERE

# Show Record Count
city_data_df.count()
# Out:
# City          561
# Lat           561
# Lng           561
# Max Temp      561
# Humidity      561
# Cloudiness    561
# Wind Speed    561
# Country       561
# Date          561
# dtype: int64

# %%
#Solution
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          572
# Lat           572
# Lng           572
# Max Temp      572
# Humidity      572
# Cloudiness    572
# Wind Speed    572
# Country       572
# Date          572
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        kerikeri -35.2268  173.9474     14.39        90         100
# 1           ginir   7.1333   40.7000     22.08        47         100
# 2  margaret river -33.9500  115.0667     15.44        67          60
# 3             bam  29.1060   58.3570     38.66        10           0
# 4       marrakesh  31.6315   -8.0083     17.04        72           0
#
#    Wind Speed Country        Date
# 0        0.98      NZ  1718607765
# 1        1.53      ET  1718607742
# 2        3.76      AU  1718607768
# 3        7.82      IR  1718607769
# 4        3.09      MA  1718607770

# %%
#Solution
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167    275.85        71          98
# 1        vilyuchinsk  52.9306  158.4028    276.30        95         100
# 2            talnakh  69.4865   88.3972    255.46        95          88
# 3             hadibu  12.6500   54.0333    299.77        85          35
# 4               alta  69.9689   23.2717    271.74        86          40
#
#    Wind Speed Country        Date
# 0       13.19      TF  1729727656
# 1        3.26      RU  1729727657
# 2        3.50      RU  1729727658
# 3        0.80      YE  1729727659
# 4        0.51      NO  1729727661

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
#Soln
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              kerikeri -35.2268  173.9474     14.39        90         100
# 1                 ginir   7.1333   40.7000     22.08        47         100
# 2        margaret river -33.9500  115.0667     15.44        67          60
# 3                   bam  29.1060   58.3570     38.66        10           0
# 4             marrakesh  31.6315   -8.0083     17.04        72           0
#
#          Wind Speed Country        Date
# City_ID
# 0              0.98      NZ  1718607765
# 1              1.53      ET  1718607742
# 2              3.76      AU  1718607768
# 3              7.82      IR  1718607769
# 4              3.09      MA  1718607770

# %%
#Soln
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167    275.85        71          98
# 1              vilyuchinsk  52.9306  158.4028    276.30        95         100
# 2                  talnakh  69.4865   88.3972    255.46        95          88
# 3                   hadibu  12.6500   54.0333    299.77        85          35
# 4                     alta  69.9689   23.2717    271.74        86          40
#
#          Wind Speed Country        Date
# City_ID
# 0             13.19      TF  1729727656
# 1              3.26      RU  1729727657
# 2              3.50      RU  1729727658
# 3              0.80      YE  1729727659
# 4              0.51      NO  1729727661

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
#Solution
# Build scatter plot for latitude vs. temperature
plt.figure(figsize=(8,8))
city_data_df['Max Temp (C)'] = city_data_df['Max Temp'] - 273.15
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp (C)'], marker="o", edgecolor="black")


# Incorporate the other graph properties
plt.grid()
plt.ylim(-7, 43)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
plt.title("City Latitude Vs Max Temperature (2024-06-17)")        
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
#Soln

# Build the scatter plots for latitude vs. humidity
plt.figure(figsize=(7,7))

plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker="o", edgecolor="black")


# Incorporate the other graph properties
plt.grid()

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude Vs Humidity (2024-06-17)")  

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
#Soln
# Build the scatter plots for latitude vs. cloudiness
plt.figure(figsize=(7,7))

plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker="o", edgecolor="black")


# Incorporate the other graph properties
plt.grid()

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude Vs Cloudiness (2024-06-17)")  

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
#Soln
# Build the scatter plots for latitude vs. wind speed
plt.figure(figsize=(7,7))

plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker="o", edgecolor="black")


# Incorporate the other graph properties
plt.grid()

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.yticks([0,2.5,5,7.5,10,12.5,15,17.5],[0,2,4,6,8,10,12,14])
plt.title("City Latitude Vs Wind Speed (2024-06-17)")  

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Solution
# Define a function to create Linear Regression plots
# YOUR CODE HERE
from scipy.stats import linregress
def model_linear_regression(x_val, y_val, line_coord, y_label, title):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
    regress_value = slope * x_val + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

    plt.scatter(x_val, y_val)
    plt.plot(x_val, regress_value, 'r-')
    plt.annotate(line_eq, line_coord, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    print(f"The r^2-value is: {rvalue ** 2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            ginir   7.1333  40.7000     22.08        47         100
# 3              bam  29.1060  58.3570     38.66        10           0
# 4        marrakesh  31.6315  -8.0083     17.04        72           0
# 6          machico  32.7000 -16.7667     20.40        81          40
# 8           howrah  22.5892  88.3103     36.00        67          40
#
#          Wind Speed Country        Date
# City_ID
# 1              1.53      ET  1718607742
# 3              7.82      IR  1718607769
# 4              3.09      MA  1718607770
# 6              5.66      PT  1718607772
# 8              6.17      IN  1718607544

# %%
#Soln
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
city_data_df.drop(columns='Max Temp (C)', inplace=True)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]
# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        vilyuchinsk  52.9306  158.4028    276.30        95         100
# 2            talnakh  69.4865   88.3972    255.46        95          88
# 3             hadibu  12.6500   54.0333    299.77        85          35
# 4               alta  69.9689   23.2717    271.74        86          40
# 5            college  64.8569 -147.8028    273.19        68          75
#
#          Wind Speed Country        Date
# City_ID
# 1              3.26      RU  1729727657
# 2              3.50      RU  1729727658
# 3              0.80      YE  1729727659
# 4              0.51      NO  1729727661
# 5              4.12      US  1729727662

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              kerikeri -35.2268  173.9474     14.39        90         100
# 2        margaret river -33.9500  115.0667     15.44        67          60
# 5              waitangi -43.9535 -176.5597     12.68        98         100
# 7          port lincoln -34.7333  135.8667     13.27        67         100
# 9                 leava -14.3000 -178.1667     28.10        85           8
#
#          Wind Speed Country        Date
# City_ID
# 0              0.98      NZ  1718607765
# 2              3.76      AU  1718607768
# 5              3.13      NZ  1718607771
# 7              3.38      AU  1718607773
# 9              8.07      WF  1718607775

# %%
#soln
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df[city_data_df['Lat'] <= 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                  port-aux-francais -49.3500   70.2167    275.85        71
# 6                            kavieng  -2.5744  150.7967    299.94        88
# 7                     puerto natales -51.7236  -72.4875    280.12        91
# 8        edinburgh of the seven seas -37.0676  -12.3116    287.38        90
# 10                     santo antonio  -6.3106  -35.4789    296.72        75
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                98       13.19      TF  1729727656
# 6               100        8.71      PG  1729727663
# 7               100        2.32      CL  1729727651
# 8               100       16.18      SH  1729727666
# 10               49        4.57      BR  1729727669

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.3940754297489331

# %%
#soln
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
model_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Max Temp']-273.15, (10,-20), "Max Temp", "Latitude Vs Max Temp")
# Out:
# The r^2-value is: 0.6950419658879935

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.6720220238897325

# %%
#Soln
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
model_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Max Temp']-273.15, (-50,30), "Max Temp", "Latitude Vs Max Temp")
# Out:
# The r^2-value is: 0.5220887551727272

# %% [markdown]
# **Discussion about the linear relationship:**
# Northern Hemisphere:
# 1. The r^2 value is 0.6950419658879935. This indicates a good relationship between latitude and temperature. We can infer that latitude does influence the temperature, but there could be other factors to consider as well.
# 2. The downward slope indicates an inverse relationship between latitude and temperature. The negative coefficient of x(-0.49) indicates that as latitude increases, temperature decreases.
# 3. Since r^2 is not a perfect 1.0, we can see some scatter points around the line, indicating that other factors should also be considered in determining the maximum temperature.
# 4. if the x value is zero, then y, i.e the temperature would be equal to the value of intercept b (32.38)
# Southern Hemisphere:
# 1. The r^2 value is 0.5220887551727272. This indicates that approximately 52% of the variance in dependent variable y (i.e temperature) can be explained by the independent variable (i.e latitude). So there could be other factors influencing the variance in dependent variable.
# 2. The upward slope in the plot indicates a positive relationship between latitude and temperature. So as the latitude increases, temperature also increases.
# 3. When x is equal to zero,  the value of y (i.e temperature) is equal to the intercept b (27.8)
# 4. Since r^2 is not a perfect 1.0, we can see lot of scatter points around the line suggesting that there are other factors that influence the temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.007659599322853922

# %%
# soln
# Northern Hemisphere
# YOUR CODE HERE
model_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], (50,20), "Humidity", "Latitude Vs Humidity")
# Out:
# The r^2-value is: 0.011028013000345923

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.00014367159540169783

# %%
#soln
# Southern Hemisphere
# YOUR CODE HERE
model_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], (-50,20), "Humidity", "Latitude Vs Humidity")
# Out:
# The r^2-value is: 0.02429944750016212

# %% [markdown]
# **Discussion about the linear relationship:**
# Northern Hemisphere:
# 1. The low r^2 value indicates a weak relationship between latitude and humidity. This means that latitude has very less influence on humidity.
# 2. For every unit increase in x, y increases by about 0.11 units. The relationship between latitude and humidity is not very significant.
# 3. In summary, the plot between latitude and humidity in the northern hemisphere shows a weak correlation.
# Southern Hemisphere:
# 1. The r^2 value indicates a weak relationship between temperature and humidity.
# 2. Though there is a slight upward trend in the slope, we cannot consider the independent variable to be a reliable predictor of the dependent variable.
# 3. The relationship between latitude and temperature in the southern hemisphere is not very meaningful.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.006456908379763574

# %%
#soln
# Northern Hemisphere
# YOUR CODE HERE
model_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], (40,10), "Cloudiness", "Latitude Vs Cloudiness")
# Out:
# The r^2-value is: 0.007229238907268983

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.018616831531634456

# %%
#soln
# Southern Hemisphere
# YOUR CODE HERE
model_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], (-30,30), "Cloudiness", "Latitude Vs Cloudiness")
# Out:
# The r^2-value is: 0.04193004588663871

# %% [markdown]
# **Discussion about the linear relationship:**
# Northern Hemisphere:
# 1. The r^2 value in the northern hemisphere is very low indicating an extremely weak relationship between latitude and cloudiness.
# 2. The equation y=0.17x+50.31 indicates that for every unit increase in x, y increases by 0.17 units. However, the low r^2 value suggests that this relationship is not statistically significant.
# Southern Hemisphere:
# 1. The equation y=0.54x+63.24 indicates that for every unit increase in x, y increases by 0.54 units. This suggests a positive linear relationship between x and y. As x increases, y increases as well.
# 2. If the r^2 value is high, it would indicate a substantial portion of variance in y can be explained by x. But the r^2 value is very low.
# 3. Though the slope of the plot is upward showing a positive trend, the r^2 value is very low suggesting that the relationship between latitude and cloudiness is not strong.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.0017236249523139959

# %%
#soln
# Northern Hemisphere
# YOUR CODE HERE
model_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], (10,12), "Wind Speed", "Latitude Vs Wind Speed")
# Out:
# The r^2-value is: 0.025470482452534037

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.06495869418886388

# %%
#soln
# Southern Hemisphere
# YOUR CODE HERE
model_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], (-50,12), "Wind Speed", "Latitude Vs Wind Speed")
# Out:
# The r^2-value is: 0.0892300110356341

# %% [markdown]
# **Discussion about the linear relationship:**
# Northern hemisphere:
# 1. The equation y = 0.02x + 2.79 indicates that for every unit increase in latitude, wind speed increase by 0.02 units. This indicates a very slight positive relationship between latitude and wind speed.
# 2. The r^2 value is very low. 2.5% of variance in wind speed can be explained by the latitude. This indicates a very weak relationship between latitude and wind speed.
# Southern Hemisphere:
# 1. The linear regression equation suggests a slight negative relationship between latitude and wind speed.
# 2. The r^2 value is very low suggesting a weak relationship between latitude and wind speed.
# 3. The negative relationship between latitude and wind speed and the low r^2 value suggests that the relationship between the 2 variables is very weak and not suitable for making predictions.
